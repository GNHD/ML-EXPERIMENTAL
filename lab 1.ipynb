# %%
import numpy
import pandas
myarray = numpy.array([[1,2,3],[4,5,6]])
rownames = ['a','b']
colnames = ['f1','f2','f3']
mydataframe=pandas.DataFrame(myarray,index=rownames,columns=colnames)
print(mydataframe)
# Out:
#    f1  f2  f3
# a   1   2   3
# b   4   5   6

# %%
import numpy
import pandas
myarray = numpy.array([['a','sandhya',9.6],[4,'shreya',6.5]])
rownames = ['r1','r2']
colnames = ['f1','f2','f3']
mydataframe = pandas.DataFrame(myarray,index=rownames,columns=colnames)
print(mydataframe)
# Out:
#    f1       f2   f3
# r1  a  sandhya  9.6
# r2  4   shreya  6.5

# %%
from pandas import read_csv
path='diabetes_dataset.csv'
data=read_csv(path)
print(data.shape)
# Out:
# (768, 9)

# %%
from pandas import read_csv
url='diabetes_dataset.csv'
data=read_csv(url)
colnames=['Pregnancies','Glu','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome']
data.columns=colnames
print(data.shape)
# Out:
# (768, 9)

# %%
description=data.describe()
print(description)
print(data)
print(data.shape)
print (data.head(4))
print(data.groupby('Outcome').size())
# Out:
#        Pregnancies         Glu  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000
#      Pregnancies  Glu  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6  148             72             35        0  33.6
# 1              1   85             66             29        0  26.6
# 2              8  183             64              0        0  23.3
# 3              1   89             66             23       94  28.1
# 4              0  137             40             35      168  43.1
# ..           ...  ...            ...            ...      ...   ...
# 763           10  101             76             48      180  32.9
# 764            2  122             70             27        0  36.8
# 765            5  121             72             23      112  26.2
# 766            1  126             60              0        0  30.1
# 767            1   93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]
# (768, 9)
#    Pregnancies  Glu  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6  148             72             35        0  33.6
# 1            1   85             66             29        0  26.6
# 2            8  183             64              0        0  23.3
# 3            1   89             66             23       94  28.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
import matplotlib.pyplot as plt
import pandas
from pandas.plotting import scatter_matrix
scatter_matrix(data[['Pregnancies','Glucose']])
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas
from pandas.plotting import scatter_matrix
scatter_matrix(data)
plt.show()
data.hist()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler
import pandas
import numpy
arr=data.values
X=arr[:,0:8]
Y=arr[:,8]
scaler=StandardScaler().fit(X)
rescaledX=scaler.transform(X)
numpy.set_printoptions(precision=3)
print(X[0:2:,:])
# Out:
# [[  6.    148.     72.     35.      0.     33.6     0.627  50.   ]
#  [  1.     85.     66.     29.      0.     26.6     0.351  31.   ]]

# %%
myarray=numpy.array([1,3,-10,4,5,7,-4,-2,10])
mydataframe=pandas.DataFrame(myarray)
print(mydataframe)
mydataframe.plot(kind='bar')
plt.show()
# Out:
#     0
# 0   1
# 1   3
# 2 -10
# 3   4
# 4   5
# 5   7
# 6  -4
# 7  -2
# 8  10

# %%
from sklearn import preprocessing
fl_x=mydataframe.values.astype(float)
min_max_scaler=preprocessing.MinMaxScaler()
X_scaled=min_max_scaler.fit_transform(fl_x)
df_normalized=pandas.DataFrame(X_scaled)
print(df_normalized)
df_normalized.plot(kind='bar')
plt.show()
# Out:
#       0
# 0  0.55
# 1  0.65
# 2  0.00
# 3  0.70
# 4  0.75
# 5  0.85
# 6  0.30
# 7  0.40
# 8  1.00

# %% [markdown]
# CANCER

# %%
import numpy
import pandas
myarray=numpy.array([[1,2,3],[4,5,6]])
rownames=['a','b']
colnames=['f1','f2','f3']
mydataframe=pandas.DataFrame(myarray,index=rownames,columns=colnames)
import numpy
import pandas
myarray = numpy.array([['a','sandhya',9.6],[4,'shreya',6.5]])
rownames = ['r1','r2']
colnames=['f1','f2','f3']
mydataframe = pandas.DataFrame(myarray, index = rownames, columns=colnames)
print(mydataframe)
# Out:
#    f1       f2   f3
# r1  a  sandhya  9.6
# r2  4   shreya  6.5

# %%
from pandas import read_csv
path='cancer_dataset.csv'
data=read_csv(path)
print(data.shape)
from pandas import read_csv
url='cancer_dataset.csv'
data=read_csv(url)
colnames=['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome']
print (data.shape)
# Out:
# (569, 33)
# (569, 33)

# %%
description=data.describe()
print(description)
print(data.shape)
print (data.head(4))
print(data.groupby('Outcome').size())
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  ...  texture_worst  perimeter_worst   area_worst  \
# count     569.000000  ...     569.000000       569.000000   569.000000
# mean        0.181162  ...      25.677223       107.261213   880.583128
# std         0.027414  ...       6.146258        33.602542   569.356993
# min         0.106000  ...      12.020000        50.410000   185.200000
# 25%         0.161900  ...      21.080000        84.110000   515.300000
# 50%         0.179200  ...      25.410000        97.660000   686.500000
# 75%         0.195700  ...      29.720000       125.400000  1084.000000
# max         0.304000  ...      49.540000       251.200000  4254.000000
#
#        smoothness_worst  compactness_worst  concavity_worst  \
# count        569.000000         569.000000       569.000000
# mean           0.132369           0.254265         0.272188
# std            0.022832           0.157336         0.208624
# min            0.071170           0.027290         0.000000
# 25%            0.116600           0.147200         0.114500
# 50%            0.131300           0.211900         0.226700
# 75%            0.146000           0.339100         0.382900
# max            0.222600           1.058000         1.252000
#
#        concave points_worst  symmetry_worst  fractal_dimension_worst  \
# count            569.000000      569.000000               569.000000
# mean               0.114606        0.290076                 0.083946
# std                0.065732        0.061867                 0.018061
# min                0.000000        0.156500                 0.055040
# 25%                0.064930        0.250400                 0.071460
# 50%                0.099930        0.282200                 0.080040
# 75%                0.161400        0.317900                 0.092080
# max                0.291000        0.663800                 0.207500
#
#        Unnamed: 32
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN
#
# [8 rows x 32 columns]
# (569, 33)
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
#
# [4 rows x 33 columns]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\gouri\OneDrive\Desktop\OFFICIAL\COLLEGE\ML\LAB 1\lab 1.ipynb Cell 14 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/gouri/OneDrive/Desktop/OFFICIAL/COLLEGE/ML/LAB%201/lab%201.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> print(data.shape)
#       <a href='vscode-notebook-cell:/c%3A/Users/gouri/OneDrive/Desktop/OFFICIAL/COLLEGE/ML/LAB%201/lab%201.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> print (data.head(4))
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gouri/OneDrive/Desktop/OFFICIAL/COLLEGE/ML/LAB%201/lab%201.ipynb#X21sZmlsZQ%3D%3D?line=4'>5</a> print(data.groupby('Outcome').size())
#
# File c:\Users\gouri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:7721, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7716 axis = self._get_axis_number(axis)
#    7718 # https://github.com/python/mypy/issues/7642
#    7719 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720 # "Union[bool, NoDefault]"; expected "bool"
# -> 7721 return DataFrameGroupBy(
#    7722     obj=self,
#    7723     keys=by,
#    7724     axis=axis,
#    7725     level=level,
#    7726     as_index=as_index,
#    7727     sort=sort,
#    7728     group_keys=group_keys,
#    7729     squeeze=squeeze,  # type: ignore[arg-type]
#    7730     observed=observed,
#    7731     dropna=dropna,
#    7732 )
#
# File c:\Users\gouri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     879 if grouper is None:
#     880     from pandas.core.groupby.grouper import get_grouper
# --> 882     grouper, exclusions, obj = get_grouper(
#     883         obj,
#     884         keys,
#     885         axis=axis,
#     886         level=level,
#     887         sort=sort,
#     888         observed=observed,
#     889         mutated=self.mutated,
#     890         dropna=self.dropna,
#     891     )
#     893 self.obj = obj
#     894 self.axis = obj._get_axis_number(axis)
#
# File c:\Users\gouri\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\groupby\grouper.py:882, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     880         in_axis, level, gpr = False, gpr, None
#     881     else:
# --> 882         raise KeyError(gpr)
#     883 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     884     # Add key to exclusions
#     885     exclusions.add(gpr.key)
#
# KeyError: 'Outcome'

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\gouri\OneDrive\Desktop\OFFICIAL\COLLEGE\ML\LAB 1\lab 1.ipynb Cell 15 in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/gouri/OneDrive/Desktop/OFFICIAL/COLLEGE/ML/LAB%201/lab%201.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> import pandas
#       <a href='vscode-notebook-cell:/c%3A/Users/gouri/OneDrive/Desktop/OFFICIAL/COLLEGE/ML/LAB%201/lab%201.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> from pandas.plotting import scatter_matrix
# ----> <a href='vscode-notebook-cell:/c%3A/Users/gouri/OneDrive/Desktop/OFFICIAL/COLLEGE/ML/LAB%201/lab%201.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> scatter_matrix(data[['Pregnancies','Glucose']])
#       <a href='vscode-notebook-cell:/c%3A/Users/gouri/OneDrive/Desktop/OFFICIAL/COLLEGE/ML/LAB%201/lab%201.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> plt.show()
#
# NameError: name 'data' is not defined
